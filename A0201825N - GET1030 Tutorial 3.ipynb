# %%
# Mount your google drive in google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Insert the directory
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
# 'A0201825N - GET1030 Tutorial 3.ipynb'	 __pycache__
# 'F1 notebook.ipynb'			 Shakespeare-completed.ipynb
#  fob					 textprocessing.py
# 'GET1030 Fundamentals.ipynb'		 Untitled0.ipynb
# 'GET1030 Tutorial 2.ipynb'		 Untitled1.ipynb
# 'Master 2018'				 Untitled2.ipynb

# %%
import pandas as pd
import seaborn as sns
import nltk
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import textprocessing as tp
# !python3 "/content/drive/My Drive/Colab Notebooks/textprocessing.py"

# %%
df = tp.make_df("/content/drive/My Drive/Colab Notebooks/fob",stopwords="default",lowercase=True)
# Out:
# Reading /content/drive/My Drive/Colab Notebooks/fob/Just One Yesterday.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/My Songs Know What You Did In The Dark (Light Em Up).txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/Tiffany Blews.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/The Phoenix.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/What a Catch, Donnie.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/I Don't Care.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/Death Valley.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/Alone Together.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/20 Dollar Nose Bleed.txt
# Reading /content/drive/My Drive/Colab Notebooks/fob/She's My Winona.txt

# %%
df.head()
# Out:
#                                                Title  ...    others
# 0                                 Just One Yesterday  ...  0.169014
# 1  My Songs Know What You Did In The Dark (Light ...  ...  0.089552
# 2                                      Tiffany Blews  ...  0.127660
# 3                                        The Phoenix  ...  0.135531
# 4                               What a Catch, Donnie  ...  0.117647
#
# [5 rows x 10 columns]

# %%
from google.colab import files
df.to_excel("fob.xlsx")
files.download('fob.xlsx')

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-08a2485f-b835-4023-a386-7efae5c9b1a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08a2485f-b835-4023-a386-7efae5c9b1a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fob-plus.xlsx to fob-plus.xlsx

# %%
df2 = pd.read_excel('fob-plus.xlsx')

# %%
df2
# Out:
#    Unnamed: 0  ... Album Single?
# 0           0  ...            No
# 1           1  ...           Yes
# 2           2  ...            No
# 3           3  ...           Yes
# 4           4  ...           Yes
# 5           5  ...           Yes
# 6           6  ...            No
# 7           7  ...           Yes
# 8           8  ...            No
# 9           9  ...            No
#
# [10 rows x 13 columns]

# %%
sns.histplot(x="nouns", data=df2, stat="probability")

# %%
sns.boxplot(x="Album Title",y="Type/token ratio", data=df2, color='White')
sns.swarmplot(x="Album Title",y="Type/token ratio", data=df2)

# %%
sns.scatterplot(data=df2,x="nouns",y="verbs",hue="Album Title")

# %% [markdown]
# **Summary and Reflection**
#
# For this tutorial's exercise, I have chosen to use 10 sets of lyrics from Fall Out Boy's songs. The 10 songs can be categorised in 2 ways:
#
# *   by album title; and
# *   whether the song was released as an album single.
#
# After performing the data preparation and visualisations, I have to say that I am generally not surprised by the analysis results. Based on the boxplot alone, it seems that the songs from *Folie à Deux* have a higher type/token ratio in general compared to those from *Save Rock and Roll*. I truly appreciate the songs more from *Folie à Deux* as I find that Fall Out Boy's more recent music tend to use a lot more fillers such as 'Ohh', which would make a song more forgettable for me in comparison.
